# %% [markdown]
# <a href="https://colab.research.google.com/github/OmniDevsOficial/API-Censo-2022/blob/Guilherme--Gr%C3%A1fico-Pop-Total-bairro%2Fregi%C3%A3o/Grafico_Pop_Total_por_Bairro_e_Regi%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

#puxa a tabela de Pop por bairro e reagião do drive e atribui as variaveis "Pop_Tabela_Bairro" e "Pop_Tabela_Regiao".
Pop_Tabela_Bairro= pd.read_excel("/content/drive/MyDrive/FATEC/API - PlanejaSJC/populacao_subsetores_completo.xlsx")
display(Pop_Tabela_Bairro) #mostra um exemplo

Pop_Tabela_Regiao= pd.read_excel("/content/drive/MyDrive/FATEC/API - PlanejaSJC/censo_2022.xlsx", sheet_name="Crescimento Populacional")
display(Pop_Tabela_Regiao) #mostra um exemplo

#cria um gráfico em relação as tabelas, nesse caso a tabela censo_2022.
Pop_Total_Regiao=px.bar(Pop_Tabela_Regiao, x="Região", y="Pop. 2022",)
Pop_Total_Regiao.show()

Pop_Bairro_Centro=px.bar(Pop_Tabela_Bairro, x="Subsetor – Nome", y="População", color="Região")
Pop_Bairro_Centro.show()
# Out:
#      Região Setor Subsetor        Subsetor – Nome  População
# 0    Centro     3    03.01                 Centro       7205
# 1    Centro     3    03.02      Jardim Bela Vista       2405
# 2    Centro     3    03.03             Vila Maria       4607
# 3    Centro     3    03.04      Vila Nova Guarani       1358
# 4    Centro   03A   03A.01                Banhado        665
# ..      ...   ...      ...                    ...        ...
# 168     Sul    16    16.07           Menino Jesus        345
# 169     Sul    16    16.08           Rio Comprido       1775
# 170     Sul    16    16.09  Palmeiras de São José       3452
# 171     Sul    28    28.01              Vila Nair       3073
# 172     Sul    28    28.02         Vila São Bento       2374
#
# [173 rows x 5 columns]
#                  Região  Pop. 2010  Pop. 2022  Crescimento Crescimento %
# 0                Centro      72115      72401          286         0,40%
# ...
